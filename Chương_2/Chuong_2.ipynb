# %%
#Câu 2.7
import json
json_data = '{"name": "Nguyen Van A", "age": 25, "city": "Hanoi"}'
python_obj = json.loads(json_data)
print(type(python_obj)) 
print(python_obj["name"])
# Out:
# <class 'dict'>
# Nguyen Van A

# %%
#Câu 2.8
import json
python_dict = {"title": "Python Programming", "author": "Author Name", "year": 2023}
json_string = json.dumps(python_dict, ensure_ascii=False)
print(json_string)
# Out:
# {"title": "Python Programming", "author": "Author Name", "year": 2023}

# %%
#Câu 2.9
import json
data = {"c": 3, "a": 1, "b": 2}
json_output = json.dumps(data, indent=4, sort_keys=True)
print(json_output)
# Out:
# {
#     "a": 1,
#     "b": 2,
#     "c": 3
# }

# %%
#Câu 2.10 - 2.11
import json
from datetime import datetime

def luu_giao_dich():
    giao_dich_list = []
    while True:
        ten = input("Nhập tên dơn vị: ")
        so_nhan_vien = input("Nhập số nhân viên: ")
        ty_le_loi_nhuan = input("Nhập tỷ lệ lợi nhuận (%): ")
        giao_dich = {"ten": ten, "so_nhan_vien": so_nhan_vien, "ty_le_loi_nhuan": ty_le_loi_nhuan}
        giao_dich_list.append(giao_dich)
        
        tiep_tuc = input("Tiếp tục? (1: Có, 0: Không): ")
        if tiep_tuc == '0':
            break
    with open('giao_dich.json', 'w', encoding='utf-8') as f:
        json.dump(giao_dich_list, f, ensure_ascii=False, indent=4)
    print("Đã lưu vào file giao_dich.json")
luu_giao_dich()
# Out:
# Đã lưu vào file giao_dich.json

# %%
#Câu 2.12
import requests
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)

if response.status_code == 200:
    posts = response.json()
    print(f"Tổng số bài post: {len(posts)}")
    print("-" * 30)
    
    for post in posts[:5]:
        print(f"User ID: {post['userId']}")
        print(f"ID: {post['id']}")
        print(f"Title: {post['title']}")
        print(f"Body: {post['body']}")
        print("-" * 20)
else:
    print("Không thể kết nối tới API.")
# Out:
# Tổng số bài post: 100
# ------------------------------
# User ID: 1
# ID: 1
# Title: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Body: quia et suscipit
# suscipit recusandae consequuntur expedita et cum
# reprehenderit molestiae ut ut quas totam
# nostrum rerum est autem sunt rem eveniet architecto
# --------------------
# User ID: 1
# ID: 2
# Title: qui est esse
# Body: est rerum tempore vitae
# sequi sint nihil reprehenderit dolor beatae ea dolores neque
# fugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis
# qui aperiam non debitis possimus qui neque nisi nulla
# --------------------
# User ID: 1
# ID: 3
# Title: ea molestias quasi exercitationem repellat qui ipsa sit aut
# Body: et iusto sed quo iure
# voluptatem occaecati omnis eligendi aut ad
# voluptatem doloribus vel accusantium quis pariatur
# molestiae porro eius odio et labore et velit aut
# --------------------
# User ID: 1
# ID: 4
# Title: eum et est occaecati
# ...
